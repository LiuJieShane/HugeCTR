# %%
# !rm -rf hugeCTR_saved_model
# !mkdir hugeCTR_saved_model

config = """{
  "solver": {
    "lr_policy": "fixed",
    "display": 1000,
    "max_iter":50000,
    "gpu": [0],
    "batchsize": 16384,
    "snapshot": 10000,
    "snapshot_prefix": "./hugeCTR_saved_model/",
    "eval_interval": 5000,
    "eval_batches": 1000,
    "mixed_precision": 1024,
    "eval_metrics": ["AUC:1.0"]
  },
  
  "optimizer": {
    "type": "SGD",
    "global_update": false,
    "sgd_hparam": {
    "learning_rate": 0.1,
    "warmup_steps": 1000,
     "decay_start": 10000,
    "decay_steps": 10000,
    "end_lr": 0.001
    }
  },


  "layers": [ 
      {
      "name": "data",
      "type": "Data",
      "slot_size_array": [138493 , 26744],
      "slot_size_array_orig": [138493 , 26744],
      "source": "./data/hugeCTR/filelist.txt",
      "eval_source": "./data/hugeCTR/test_filelist.txt",
      "check": "None",
      "cache_eval_data": true,
      "label": {
              "top": "label",
              "label_dim": 1
      },
      "dense": {
              "top": "dense",
              "dense_dim": 1
      },
      "sparse": [
              {
          "top": "data1",
          "type": "LocalizedSlot",
          "max_feature_num_per_sample": 2,
          "max_nnz": 1,
          "slot_num": 2
              }
      ]
    },

    {
      "name": "sparse_embedding1",
      "type": "LocalizedSlotSparseEmbeddingOneHot",
      "bottom": "data1",
      "top": "sparse_embedding1",
      "sparse_embedding_hparam": {
        "slot_size_array": [138493 , 26744],
        "embedding_vec_size": 64,
        "combiner": 0
      }
    },

    {
      "name": "fc1",
      "type": "FusedInnerProduct",
      "bottom": "dense",
      "top": "fc1",
      "fc_param": {
        "num_output": 64
      }
    },

    {
      "name": "fc2",
      "type": "FusedInnerProduct",
      "bottom": "fc1",
      "top": "fc2",
      "fc_param": {
        "num_output": 128
      }
    },

   
    {
      "name": "fc3",
      "type": "FusedInnerProduct",
      "bottom": "fc2",
      "top": "fc3",
      "fc_param": {
        "num_output": 64
      }
    },

    {
      "name": "interaction1",
      "type": "Interaction",
      "bottom": ["fc3", "sparse_embedding1"],
      "top": "interaction1"
    },

    {
      "name": "fc4",
      "type": "FusedInnerProduct",
      "bottom": "interaction1",
      "top": "fc4",
       "fc_param": {
        "num_output": 1024
      }
    },

    {
      "name": "fc5",
      "type": "FusedInnerProduct",
      "bottom": "fc4",
      "top": "fc5",
      "fc_param": {
        "num_output": 1024
      }
    },

    {
      "name": "fc6",
      "type": "FusedInnerProduct",
      "bottom": "fc5",
      "top": "fc6",
      "fc_param": {
        "num_output": 512
      }
    },

    {
      "name": "fc7",
      "type": "FusedInnerProduct",
      "bottom": "fc6",
      "top": "fc7",
      "fc_param": {
        "num_output": 256
      }
    },

    {
      "name": "fc8",
      "type": "InnerProduct",
      "bottom": "fc7",
      "top": "fc8",
      "fc_param": {
        "num_output": 1
      }
    },
    
    {
      "name": "loss",
      "type": "BinaryCrossEntropyLoss",
      "bottom": ["fc8","label"],
      "top": "loss"
    } 
  ]
}
"""

# %%
with open('./movie_lens.json', 'wt') as f:
    for line in config:
        f.write(line)

# %%
# !../build/bin/huge_ctr --train ./movie_lens.json
# Out:
# [0, init_start, ]
# HugeCTR Version: 2.2
# Config file: ./movie_lens.json
# [10d14h19m11s][HUGECTR][INFO]: batchsize_eval is not specified using default: 16384
# Mixed Precision training with scaler: 1024 is enabled.
# [10d14h19m11s][HUGECTR][INFO]: algorithm_search is not specified using default: 1
# [10d14h19m11s][HUGECTR][INFO]: Algorithm search: ON
# [10d14h19m12s][HUGECTR][INFO]: Peer-to-peer access cannot be fully enabled.
# Device 0: Tesla V100-SXM2-16GB
# [10d14h19m12s][HUGECTR][INFO]: Initial seed is 731223175
# [10d14h19m12s][HUGECTR][INFO]: num_internal_buffers 1
# [10d14h19m12s][HUGECTR][INFO]: num_internal_buffers 1
# [10d14h19m12s][HUGECTR][INFO]: max_vocabulary_size_per_gpu_=165237
# [10d14h19m29s][HUGECTR][INFO]: gpu0 start to init embedding of slot0 , slot_size=138493, key_offset=0, value_index_offset=0
# [10d14h19m29s][HUGECTR][INFO]: gpu0 start to init embedding of slot1 , slot_size=26744, key_offset=138493, value_index_offset=138493
# [10d14h19m29s][HUGECTR][INFO]: decay_power is not specified using default: 2.000000
# [17885.9, init_end, ]
# [17885.9, run_start, ]
# HugeCTR training start:
# [17885.9, train_epoch_start, 0, ]
# [10d14h19m33s][HUGECTR][INFO]: Iter: 1000 Time(1000 iters): 4.140984s Loss: 0.678341 lr:0.100000
# [10d14h19m37s][HUGECTR][INFO]: Iter: 2000 Time(1000 iters): 4.138172s Loss: 0.681096 lr:0.100000
# [10d14h19m41s][HUGECTR][INFO]: Iter: 3000 Time(1000 iters): 4.141401s Loss: 0.681339 lr:0.100000
# [10d14h19m45s][HUGECTR][INFO]: Iter: 4000 Time(1000 iters): 4.151303s Loss: 0.680352 lr:0.100000
# [10d14h19m49s][HUGECTR][INFO]: Iter: 5000 Time(1000 iters): 4.152973s Loss: 0.680122 lr:0.100000
# [38611.4, eval_start, 0.1, ]
# [10d14h19m51s][HUGECTR][INFO]: Evaluation, AUC: 0.671246
# [40322.1, eval_accuracy, 0.671246, 0.1, 5000, ]
# [10d14h19m51s][HUGECTR][INFO]: Eval Time for 1000 iters: 1.710673s
# [40322.1, eval_stop, 0.1, ]
# [10d14h19m55s][HUGECTR][INFO]: Iter: 6000 Time(1000 iters): 5.867252s Loss: 0.679198 lr:0.100000
# [10d14h20m00s][HUGECTR][INFO]: Iter: 7000 Time(1000 iters): 4.163094s Loss: 0.679793 lr:0.100000
# [10d14h20m04s][HUGECTR][INFO]: Iter: 8000 Time(1000 iters): 4.174977s Loss: 0.664420 lr:0.100000
# [10d14h20m08s][HUGECTR][INFO]: Iter: 9000 Time(1000 iters): 4.184394s Loss: 0.301707 lr:0.100000
# [10d14h20m12s][HUGECTR][INFO]: Iter: 10000 Time(1000 iters): 4.189291s Loss: 0.266808 lr:0.099980
# [10d14h20m12s][HUGECTR][INFO]: Rank0: Dump embedding table from GPU0
# [10d14h20m12s][HUGECTR][INFO]: Rank0: Write hash table <key,value> pairs to file
# [10d14h20m12s][HUGECTR][INFO]: Done
# [61326, eval_start, 0.2, ]
# [10d14h20m14s][HUGECTR][INFO]: Evaluation, AUC: 0.947372
# [62883.2, eval_accuracy, 0.947372, 0.2, 10000, ]
# [10d14h20m14s][HUGECTR][INFO]: Eval Time for 1000 iters: 1.557162s
# [62883.2, eval_stop, 0.2, ]
# [10d14h20m18s][HUGECTR][INFO]: Iter: 11000 Time(1000 iters): 5.886069s Loss: 0.270134 lr:0.080982
# [10d14h20m22s][HUGECTR][INFO]: Iter: 12000 Time(1000 iters): 4.197303s Loss: 0.268928 lr:0.063984
# [10d14h20m26s][HUGECTR][INFO]: Iter: 13000 Time(1000 iters): 4.199216s Loss: 0.264129 lr:0.048986
# [10d14h20m31s][HUGECTR][INFO]: Iter: 14000 Time(1000 iters): 4.201141s Loss: 0.260654 lr:0.035988
# [10d14h20m35s][HUGECTR][INFO]: Iter: 15000 Time(1000 iters): 4.199961s Loss: 0.248192 lr:0.024990
# [83875.4, eval_start, 0.3, ]
# [10d14h20m36s][HUGECTR][INFO]: Evaluation, AUC: 0.948700
# [85429.3, eval_accuracy, 0.9487, 0.3, 15000, ]
# [10d14h20m36s][HUGECTR][INFO]: Eval Time for 1000 iters: 1.553852s
# [85429.3, eval_stop, 0.3, ]
# [10d14h20m40s][HUGECTR][INFO]: Iter: 16000 Time(1000 iters): 5.753890s Loss: 0.242830 lr:0.015992
# [10d14h20m45s][HUGECTR][INFO]: Iter: 17000 Time(1000 iters): 4.200255s Loss: 0.235992 lr:0.008994
# [10d14h20m49s][HUGECTR][INFO]: Iter: 18000 Time(1000 iters): 4.199536s Loss: 0.224590 lr:0.003996
# [10d14h20m53s][HUGECTR][INFO]: Iter: 19000 Time(1000 iters): 4.202495s Loss: 0.230048 lr:0.001000
# [10d14h20m57s][HUGECTR][INFO]: Iter: 20000 Time(1000 iters): 4.198729s Loss: 0.231836 lr:340282357297095883993259180032.000000
# [10d14h20m57s][HUGECTR][INFO]: Rank0: Dump embedding table from GPU0
# [10d14h20m57s][HUGECTR][INFO]: Rank0: Write hash table <key,value> pairs to file
# [10d14h20m57s][HUGECTR][INFO]: Done
# [106562, eval_start, 0.4, ]
# [10d14h20m59s][HUGECTR][INFO]: Evaluation, AUC: 0.693114
# [108109, eval_accuracy, 0.693114, 0.4, 20000, ]
# [10d14h20m59s][HUGECTR][INFO]: Eval Time for 1000 iters: 1.547161s
# [108109, eval_stop, 0.4, ]
# Train Runtime error: Loss cannot converge /hugectr/HugeCTR/src/main.cpp:93
#
# Terminated with error
