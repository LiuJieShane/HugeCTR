# %%
#!rm -rf ./saved_model
#!python -m torch.distributed.launch --nproc_per_node=1 --use_env ../ncf.py --epochs 50 --data /data/cache/ml-20m --checkpoint_dir ./saved_model
# Out:
# DLL 2020-08-07 12:45:29.297777 - PARAMETER data : /data/cache/ml-20m  epochs : 50  batch_size : 1048576  valid_batch_size : 1048576  factors : 64  layers : [256, 256, 128, 64]  negative_samples : 4  learning_rate : 0.0045  topk : 10  seed : None  threshold : 1.0  beta1 : 0.25  beta2 : 0.5  eps : 1e-08  dropout : 0.5  checkpoint_dir : ./saved_model  load_checkpoint_path : None  mode : train  grads_accumulated : 1  amp : False  log_path : log.json  world_size : 1  distributed : False  local_rank : 0
# Saving results to ./saved_model
# NeuMF(
#   (mf_user_embed): Embedding(138493, 64)
#   (mf_item_embed): Embedding(26744, 64)
#   (mlp_user_embed): Embedding(138493, 128)
#   (mlp_item_embed): Embedding(26744, 128)
#   (mlp): ModuleList(
#     (0): Linear(in_features=256, out_features=256, bias=True)
#     (1): Linear(in_features=256, out_features=128, bias=True)
#     (2): Linear(in_features=128, out_features=64, bias=True)
#   )
#   (final): Linear(in_features=128, out_features=1, bias=True)
# )
# 31832577 parameters
# ../ncf.py:132: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:20.)
#   temp[dup_mask] = -1
# ../ncf.py:139: UserWarning: This overload of nonzero is deprecated:
# 	nonzero(Tensor input, *, Tensor out)
# Consider using one of the following signatures instead:
# 	nonzero(Tensor input, *, bool as_tuple) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:760.)
#   ndcg = (math.log(2) / (torch.nonzero(ifzero)[:,1].view(-1).to(torch.float)+2).log_()).sum()
# DLL 2020-08-07 12:45:43.849376 - (0,) train_throughput : 9922206.182770079  hr@10 : 0.8749034247218271  train_epoch_time : 10.008746862411499  validation_epoch_time : 0.47252535820007324  eval_throughput : 29602206.013412282
# New best hr!
# Saving the model to:  ./saved_model/model.pth
# DLL 2020-08-07 12:45:54.336677 - (1,) train_throughput : 10189467.3581901  hr@10 : 0.9039518242799275  train_epoch_time : 9.746225833892822  validation_epoch_time : 0.4752650260925293  eval_throughput : 29431563.931819208
# New best hr!
# Saving the model to:  ./saved_model/model.pth
# DLL 2020-08-07 12:46:04.889301 - (2,) train_throughput : 10163860.68434625  hr@10 : 0.9285306838612782  train_epoch_time : 9.770780324935913  validation_epoch_time : 0.47690558433532715  eval_throughput : 29330319.16473586
# New best hr!
# Saving the model to:  ./saved_model/model.pth
# DLL 2020-08-07 12:46:15.426478 - (3,) train_throughput : 10160167.418854088  hr@10 : 0.9294549182991199  train_epoch_time : 9.774332046508789  validation_epoch_time : 0.4758644104003906  eval_throughput : 29394492.83091106
# New best hr!
# Saving the model to:  ./saved_model/model.pth
# DLL 2020-08-07 12:46:25.972427 - (4,) train_throughput : 10144751.037423871  hr@10 : 0.9444015220985899  train_epoch_time : 9.789185523986816  validation_epoch_time : 0.47376179695129395  eval_throughput : 29524949.22556629
# New best hr!
# Saving the model to:  ./saved_model/model.pth
# DLL 2020-08-07 12:46:36.528561 - (5,) train_throughput : 10139570.471850907  hr@10 : 0.9428057735770039  train_epoch_time : 9.794187068939209  validation_epoch_time : 0.47617506980895996  eval_throughput : 29375315.69137347
# DLL 2020-08-07 12:46:46.811019 - (6,) train_throughput : 10126305.144085085  hr@10 : 0.9479396070559523  train_epoch_time : 9.80701732635498  validation_epoch_time : 0.47519373893737793  eval_throughput : 29435979.167737607
# New best hr!
# Saving the model to:  ./saved_model/model.pth
# DLL 2020-08-07 12:46:57.363416 - (7,) train_throughput : 10148270.408471217  hr@10 : 0.9494703703436275  train_epoch_time : 9.78579068183899  validation_epoch_time : 0.47660279273986816  eval_throughput : 29348953.07597284
# New best hr!
# Saving the model to:  ./saved_model/model.pth
# DLL 2020-08-07 12:47:07.914123 - (8,) train_throughput : 10151584.39233849  hr@10 : 0.9484522683456925  train_epoch_time : 9.782596111297607  validation_epoch_time : 0.4770009517669678  eval_throughput : 29324455.11520393
# DLL 2020-08-07 12:47:18.176077 - (9,) train_throughput : 10148502.828742703  hr@10 : 0.9536944105478256  train_epoch_time : 9.785566568374634  validation_epoch_time : 0.476179838180542  eval_throughput : 29375021.532718852
# New best hr!
# Saving the model to:  ./saved_model/model.pth
# DLL 2020-08-07 12:47:28.714190 - (10,) train_throughput : 10157603.521205276  hr@10 : 0.9499108258179114  train_epoch_time : 9.776799201965332  validation_epoch_time : 0.47480106353759766  eval_throughput : 29460323.64751087
# DLL 2020-08-07 12:47:38.964454 - (11,) train_throughput : 10161408.455218524  hr@10 : 0.9500263551226416  train_epoch_time : 9.773138284683228  validation_epoch_time : 0.4769115447998047  eval_throughput : 29329952.5929315
# DLL 2020-08-07 12:47:49.223273 - (12,) train_throughput : 10150834.296238743  hr@10 : 0.9578462449365672  train_epoch_time : 9.783318996429443  validation_epoch_time : 0.4753248691558838  eval_throughput : 29427858.518828463
# New best hr!
# Saving the model to:  ./saved_model/model.pth
# DLL 2020-08-07 12:47:59.760823 - (13,) train_throughput : 10155264.734440288  hr@10 : 0.9577234950502913  train_epoch_time : 9.779050827026367  validation_epoch_time : 0.474027156829834  eval_throughput : 29508421.191618208
# DLL 2020-08-07 12:48:09.990380 - (14,) train_throughput : 10182251.616903586  hr@10 : 0.9583155827370337  train_epoch_time : 9.753132581710815  validation_epoch_time : 0.4762115478515625  eval_throughput : 29373065.52750809
# New best hr!
# Saving the model to:  ./saved_model/model.pth
# DLL 2020-08-07 12:48:20.534823 - (15,) train_throughput : 10157234.701951116  hr@10 : 0.9565176579321698  train_epoch_time : 9.777154207229614  validation_epoch_time : 0.4768202304840088  eval_throughput : 29335569.478252478
# DLL 2020-08-07 12:48:30.782615 - (16,) train_throughput : 10163939.304189086  hr@10 : 0.9587560382113175  train_epoch_time : 9.770704746246338  validation_epoch_time : 0.47686100006103516  eval_throughput : 29333061.412465375
# New best hr!
# Saving the model to:  ./saved_model/model.pth
# DLL 2020-08-07 12:48:41.292693 - (17,) train_throughput : 10183764.707804905  hr@10 : 0.9554201295372329  train_epoch_time : 9.751683473587036  validation_epoch_time : 0.4743349552154541  eval_throughput : 29489273.025738563
# DLL 2020-08-07 12:48:51.542600 - (18,) train_throughput : 10159455.948757874  hr@10 : 0.9585610825095853  train_epoch_time : 9.77501654624939  validation_epoch_time : 0.4746818542480469  eval_throughput : 29467722.16974324
# DLL 2020-08-07 12:49:01.788187 - (19,) train_throughput : 10164016.68515898  hr@10 : 0.9581567299430296  train_epoch_time : 9.770630359649658  validation_epoch_time : 0.47478365898132324  eval_throughput : 29461403.60014
# DLL 2020-08-07 12:49:12.039298 - (20,) train_throughput : 10158565.450549515  hr@10 : 0.9579328919151149  train_epoch_time : 9.77587342262268  validation_epoch_time : 0.47505879402160645  eval_throughput : 29444340.73430459
# DLL 2020-08-07 12:49:22.268334 - (21,) train_throughput : 10184076.941455962  hr@10 : 0.9574635541146483  train_epoch_time : 9.751384496688843  validation_epoch_time : 0.4774661064147949  eval_throughput : 29295886.790858857
# DLL 2020-08-07 12:49:32.507438 - (22,) train_throughput : 10170151.882729951  hr@10 : 0.9565104373506242  train_epoch_time : 9.76473617553711  validation_epoch_time : 0.4741973876953125  eval_throughput : 29497828.041574154
# DLL 2020-08-07 12:49:42.754119 - (23,) train_throughput : 10162885.601778481  hr@10 : 0.9575646422562873  train_epoch_time : 9.77171778678894  validation_epoch_time : 0.4747598171234131  eval_throughput : 29462883.115830112
# DLL 2020-08-07 12:49:52.994644 - (24,) train_throughput : 10168822.069044717  hr@10 : 0.957911230170478  train_epoch_time : 9.766013145446777  validation_epoch_time : 0.47434568405151367  eval_throughput : 29488606.032053478
# DLL 2020-08-07 12:50:03.247818 - (25,) train_throughput : 10159292.902074337  hr@10 : 0.9562432758334356  train_epoch_time : 9.775173425674438  validation_epoch_time : 0.4778153896331787  eval_throughput : 29274471.487279844
# DLL 2020-08-07 12:50:13.496492 - (26,) train_throughput : 10162380.527023885  hr@10 : 0.9568498046832692  train_epoch_time : 9.77220344543457  validation_epoch_time : 0.47629451751708984  eval_throughput : 29367948.791260455
# DLL 2020-08-07 12:50:23.730312 - (27,) train_throughput : 10176735.060483348  hr@10 : 0.9577234950502913  train_epoch_time : 9.758419513702393  validation_epoch_time : 0.47522592544555664  eval_throughput : 29433985.50254911
# DLL 2020-08-07 12:50:33.975841 - (28,) train_throughput : 10163073.06497709  hr@10 : 0.956315481648892  train_epoch_time : 9.77153754234314  validation_epoch_time : 0.4738273620605469  eval_throughput : 29520863.757573806
# DLL 2020-08-07 12:50:44.223208 - (29,) train_throughput : 10164592.367117403  hr@10 : 0.9579978771490256  train_epoch_time : 9.770076990127563  validation_epoch_time : 0.47710537910461426  eval_throughput : 29318036.669909175
# DLL 2020-08-07 12:50:54.479742 - (30,) train_throughput : 10153282.908698201  hr@10 : 0.9561999523441618  train_epoch_time : 9.780959606170654  validation_epoch_time : 0.47541284561157227  eval_throughput : 29422412.81260726
# DLL 2020-08-07 12:51:04.729210 - (31,) train_throughput : 10160314.879842326  hr@10 : 0.9573263630652813  train_epoch_time : 9.774190187454224  validation_epoch_time : 0.47510576248168945  eval_throughput : 29441429.8974938
# DLL 2020-08-07 12:51:14.980635 - (32,) train_throughput : 10157902.757580295  hr@10 : 0.9564165697905309  train_epoch_time : 9.776511192321777  validation_epoch_time : 0.4747438430786133  eval_throughput : 29463874.474478964
# DLL 2020-08-07 12:51:25.233052 - (33,) train_throughput : 10157848.011859568  hr@10 : 0.9556150852389651  train_epoch_time : 9.776563882827759  validation_epoch_time : 0.4756796360015869  eval_throughput : 29405910.914280415
# DLL 2020-08-07 12:51:35.492165 - (34,) train_throughput : 10149278.54663773  hr@10 : 0.9565898637476262  train_epoch_time : 9.784818649291992  validation_epoch_time : 0.47412872314453125  eval_throughput : 29502099.993499074
# DLL 2020-08-07 12:51:45.728308 - (35,) train_throughput : 10174365.337765455  hr@10 : 0.9565609814214436  train_epoch_time : 9.760692358016968  validation_epoch_time : 0.47527599334716797  eval_throughput : 29430884.782313295
# DLL 2020-08-07 12:51:55.960413 - (36,) train_throughput : 10179023.301416302  hr@10 : 0.9562504964149813  train_epoch_time : 9.756225824356079  validation_epoch_time : 0.4757115840911865  eval_throughput : 29403936.056597598
# DLL 2020-08-07 12:52:06.202991 - (37,) train_throughput : 10169869.057162818  hr@10 : 0.9562938199042551  train_epoch_time : 9.765007734298706  validation_epoch_time : 0.47739434242248535  eval_throughput : 29300290.675881233
# DLL 2020-08-07 12:52:16.449290 - (38,) train_throughput : 10166037.439974884  hr@10 : 0.9572180543420967  train_epoch_time : 9.768688201904297  validation_epoch_time : 0.4774322509765625  eval_throughput : 29297964.206206653
# DLL 2020-08-07 12:52:26.692818 - (39,) train_throughput : 10166283.577448871  hr@10 : 0.9564887756059873  train_epoch_time : 9.768451690673828  validation_epoch_time : 0.4749124050140381  eval_throughput : 29453416.78237807
# DLL 2020-08-07 12:52:36.924730 - (40,) train_throughput : 10176769.870048692  hr@10 : 0.9554201295372329  train_epoch_time : 9.758386135101318  validation_epoch_time : 0.4733603000640869  eval_throughput : 29549991.830971528
# DLL 2020-08-07 12:52:47.167463 - (41,) train_throughput : 10168364.560473891  hr@10 : 0.9565609814214436  train_epoch_time : 9.766452550888062  validation_epoch_time : 0.47610926628112793  eval_throughput : 29379375.68251536
# DLL 2020-08-07 12:52:57.410459 - (42,) train_throughput : 10167544.474526003  hr@10 : 0.9547919389427625  train_epoch_time : 9.767240285873413  validation_epoch_time : 0.4755363464355469  eval_throughput : 29414771.56235811
# DLL 2020-08-07 12:53:07.655951 - (43,) train_throughput : 10166091.777767055  hr@10 : 0.9558894673376994  train_epoch_time : 9.768635988235474  validation_epoch_time : 0.4766409397125244  eval_throughput : 29346604.193161488
# DLL 2020-08-07 12:53:17.904511 - (44,) train_throughput : 10162382.262590002  hr@10 : 0.9552179532539551  train_epoch_time : 9.772201776504517  validation_epoch_time : 0.47611570358276367  eval_throughput : 29378978.4599459
# DLL 2020-08-07 12:53:28.155379 - (45,) train_throughput : 10159146.957430271  hr@10 : 0.9545175568440282  train_epoch_time : 9.77531385421753  validation_epoch_time : 0.47509312629699707  eval_throughput : 29442212.959435135
# DLL 2020-08-07 12:53:38.382103 - (46,) train_throughput : 10184656.143246317  hr@10 : 0.9563876874643483  train_epoch_time : 9.750829935073853  validation_epoch_time : 0.47565197944641113  eval_throughput : 29407620.70680276
# DLL 2020-08-07 12:53:48.621008 - (47,) train_throughput : 10172861.746597819  hr@10 : 0.956077202457886  train_epoch_time : 9.762135028839111  validation_epoch_time : 0.47627854347229004  eval_throughput : 29368933.771449253
# DLL 2020-08-07 12:53:58.863371 - (48,) train_throughput : 10167617.194720307  hr@10 : 0.9565826431660805  train_epoch_time : 9.767170429229736  validation_epoch_time : 0.4750232696533203  eval_throughput : 29446542.714020133
# DLL 2020-08-07 12:54:09.110392 - (49,) train_throughput : 10162249.12159674  hr@10 : 0.9547847183612168  train_epoch_time : 9.772329807281494  validation_epoch_time : 0.47452402114868164  eval_throughput : 29477523.53219066
# DLL 2020-08-07 12:54:09.111131 - () best_train_throughput : 10189467.3581901  best_eval_throughput : 29602206.013412282  mean_train_throughput : 10158458.513871187  mean_eval_throughput : 29415390.67691937  best_accuracy : 0.9587560382113175  best_epoch : 16  time_to_target : 518.0293047428131  time_to_best_model : 179.98483657836914

# %%
# !ls -l saved_model
# Out:
# total 124356
# -rw-r--r-- 1 26622 dip 127332376 Aug  8 02:30 model.pth

# %%
import sys
sys.path.insert(0, "/mnt/dldata/vinhn/DeepLearningExamples/PyTorch/Recommendation/NCF")

import torch.jit
import time
from argparse import ArgumentParser
import numpy as np
import torch

from neumf import NeuMF

# %%
def parse_args():
    parser = ArgumentParser(description="Benchmark inference performance of the NCF model")
    parser.add_argument('-f', '--file', help='Path for input file. First line should contain number of lines to search in')
    parser.add_argument('--load_checkpoint_path', default=None, type=str,
                        help='Path to the checkpoint file to be loaded before training/evaluation')
    parser.add_argument('--n_users', default=138493, type=int,
                        help='Number of users. Defaults to the number of users in the ml-20m dataset after preprocessing')
    parser.add_argument('--n_items', default=26744, type=int,
                        help='Number of items. Defaults to the number of users in the ml-20m dataset after preprocessing')
    parser.add_argument('-fac', '--factors', type=int, default=64,
                        help='Number of predictive factors')
    parser.add_argument('--dropout', type=float, default=0.5,
                        help='Dropout probability, if equal to 0 will not use dropout at all')
    parser.add_argument('--layers', nargs='+', type=int,
                        default=[256, 256, 128, 64],
                        help='Sizes of hidden layers for MLP')
    parser.add_argument('--batch_sizes', default='1,4,16,64,256,1024,4096,16384,65536,262144,1048576', type=str,
                        help='A list of comma-separated batch size values to benchmark')
    parser.add_argument('--num_batches', default=200, type=int,
                        help='Number of batches for which to measure latency and throughput')
    parser.add_argument('--fp16', action='store_true', help='Cast the model to FP16 precision', default=False)
    parser.add_argument('--log_path', default='log.json', type=str,
                        help='Path for the JSON training log')

    return parser.parse_args()

# %%
args = parse_args()

# %%
from scipy.spatial.distance import cdist
def find_similar_movies(nn_movie_id, item_embedding, item_embedding_norm=None, k=10):
    sim = 1-cdist(item_embedding, item_embedding[nn_movie_id].reshape(1, -1), metric="cosine")

    return sim.squeeze().argsort()[-k:][::-1]

# %%
model = NeuMF(nb_users=args.n_users, nb_items=args.n_items, mf_dim=args.factors,
              mlp_layer_sizes=args.layers, dropout=args.dropout)

model = model.cuda()

state_dict = torch.load("./saved_model/model.pth")
model.load_state_dict(state_dict)

#find nearest neighbor
item_embedding = model.mf_item_embed.weight
item_embedding = item_embedding.detach().cpu().numpy()

import pickle

with open('./mappings.pickle', 'rb') as handle:
    movies_mapping = pickle.load(handle)["items"]

nn_to_movies = movies_mapping
movies_to_nn = {}
for i in range(len(movies_mapping)):
    movies_to_nn[movies_mapping[i]] = i

import pandas as pd
movies = pd.read_csv("/mnt/dldata/vinhn/DeepLearningExamples/PyTorch/Recommendation/NCF/data/ml-20m/movies.csv", index_col="movieId")

movie_ID = 2
print("Query: ", movies.loc[movie_ID]["title"], movies.loc[movie_ID]["genres"])

print("Similar movies: ")
similar_movies = find_similar_movies(movies_to_nn[movie_ID], item_embedding)

for i in similar_movies:
    print(nn_to_movies[i], movies.loc[nn_to_movies[i]]["title"], movies.loc[nn_to_movies[i]]["genres"])
# Out:
# Query:  Jumanji (1995) Adventure|Children|Fantasy
# Similar movies:
# 2 Jumanji (1995) Adventure|Children|Fantasy
# 367 Mask, The (1994) Action|Comedy|Crime|Fantasy
# 2054 Honey, I Shrunk the Kids (1989) Adventure|Children|Comedy|Fantasy|Sci-Fi
# 586 Home Alone (1990) Children|Comedy
# 1917 Armageddon (1998) Action|Romance|Sci-Fi|Thriller
# 2012 Back to the Future Part III (1990) Adventure|Comedy|Sci-Fi|Western
# 317 Santa Clause, The (1994) Comedy|Drama|Fantasy
# 208 Waterworld (1995) Action|Adventure|Sci-Fi
# 788 Nutty Professor, The (1996) Comedy|Fantasy|Romance|Sci-Fi
# 2617 Mummy, The (1999) Action|Adventure|Comedy|Fantasy|Horror|Thriller

# %%
movie_ID = 318  
print("Query: ", movies.loc[movie_ID]["title"], movies.loc[movie_ID]["genres"])

print("Similar movies: ")
similar_movies = find_similar_movies(movies_to_nn[movie_ID], item_embedding)

for i in similar_movies:
    print(nn_to_movies[i], movies.loc[nn_to_movies[i]]["title"], movies.loc[nn_to_movies[i]]["genres"])
# Out:
# Query:  Shawshank Redemption, The (1994) Crime|Drama
# Similar movies:
# 318 Shawshank Redemption, The (1994) Crime|Drama
# 527 Schindler's List (1993) Drama|War
# 593 Silence of the Lambs, The (1991) Crime|Horror|Thriller
# 296 Pulp Fiction (1994) Comedy|Crime|Drama|Thriller
# 50 Usual Suspects, The (1995) Crime|Mystery|Thriller
# 356 Forrest Gump (1994) Comedy|Drama|Romance|War
# 110 Braveheart (1995) Action|Drama|War
# 47 Seven (a.k.a. Se7en) (1995) Mystery|Thriller
# 480 Jurassic Park (1993) Action|Adventure|Sci-Fi|Thriller
# 457 Fugitive, The (1993) Thriller

# %%
# !cat /mnt/dldata/vinhn/DeepLearningExamples/PyTorch/Recommendation/NCF/data/ml-20m/movies.csv| grep Star
# Out:
# 124,"Star Maker, The (Uomo delle stelle, L') (1995)",Drama
# 131,Frankie Starlight (1995),Drama|Romance
# 197,"Stars Fell on Henrietta, The (1995)",Drama
# 260,Star Wars: Episode IV - A New Hope (1977),Action|Adventure|Sci-Fi
# 316,Stargate (1994),Action|Adventure|Sci-Fi
# 329,Star Trek: Generations (1994),Adventure|Drama|Sci-Fi
# 800,Lone Star (1996),Drama|Mystery|Western
# 1038,Unhook the Stars (1996),Drama
# 1118,North Star (a.k.a. Tashunga) (1995),Action|Adventure|Crime|Drama|Western
# 1196,Star Wars: Episode V - The Empire Strikes Back (1980),Action|Adventure|Sci-Fi
# 1210,Star Wars: Episode VI - Return of the Jedi (1983),Action|Adventure|Sci-Fi
# 1356,Star Trek: First Contact (1996),Action|Adventure|Sci-Fi|Thriller
# 1371,Star Trek: The Motion Picture (1979),Adventure|Sci-Fi
# 1372,Star Trek VI: The Undiscovered Country (1991),Action|Mystery|Sci-Fi
# 1373,Star Trek V: The Final Frontier (1989),Action|Sci-Fi
# 1374,Star Trek II: The Wrath of Khan (1982),Action|Adventure|Sci-Fi|Thriller
# 1375,Star Trek III: The Search for Spock (1984),Action|Adventure|Sci-Fi
# 1376,Star Trek IV: The Voyage Home (1986),Adventure|Comedy|Sci-Fi
# 1410,"Evening Star, The (1996)",Comedy|Drama
# 1613,Star Maps (1997),Drama
# 1676,Starship Troopers (1997),Action|Sci-Fi
# 1750,Star Kid (1997),Adventure|Children|Fantasy|Sci-Fi
# 2246,Stars and Bars (1988),Action|Comedy|Romance
# 2290,Stardust Memories (1980),Comedy|Drama
# 2393,Star Trek: Insurrection (1998),Action|Drama|Romance|Sci-Fi
# 2628,Star Wars: Episode I - The Phantom Menace (1999),Action|Adventure|Sci-Fi
# 3166,Brenda Starr (1989),Adventure
# 3202,Even Dwarfs Started Small (Auch Zwerge haben klein angefangen) (1971),Drama|Horror
# 3217,"Star Is Born, A (1937)",Drama
# 3699,Starman (1984),Adventure|Drama|Romance|Sci-Fi
# 3976,Stardom (2000),Comedy|Drama
# 4198,Battle Beyond the Stars (1980),Sci-Fi
# 4304,Startup.com (2001),Documentary
# 4755,Wish Upon a Star (1996),Comedy
# 4757,Rock Star (2001),Comedy|Drama|Musical
# 5378,Star Wars: Episode II - Attack of the Clones (2002),Action|Adventure|Sci-Fi|IMAX
# 5549,Flaming Star (1960),Western
# 5849,I'm Starting From Three (Ricomincio da Tre) (1981),Comedy
# 5906,It All Starts Today (��a commence aujourd'hui) (1999),Drama
# 5944,Star Trek: Nemesis (2002),Action|Drama|Sci-Fi|Thriller
# 6107,"Night of the Shooting Stars (Notte di San Lorenzo, La) (1982)",Drama|War
# 6134,Starstruck (1982),Comedy|Musical
# 6146,To Begin Again (a.k.a. Starting Over) (Volver a Empezar) (1982),Drama
# 6430,Ziggy Stardust and the Spiders from Mars (1973),Documentary|Musical
# 6528,Start the Revolution Without Me (1970),Comedy
# 6702,Dickie Roberts: Former Child Star (2003),Comedy
# 7325,Starsky & Hutch (2004),Action|Comedy|Crime|Thriller
# 7400,Beyond the Stars (1989),Drama|Sci-Fi
# 8398,Star! (1968),Musical
# 8633,"Last Starfighter, The (1984)",Action|Adventure|Comedy|Sci-Fi
# 8657,"Tin Star, The (1957)",Western
# 8676,Fist of the North Star (1995),Action|Thriller
# 25872,It Started with Eve (1941),Comedy|Musical|Romance
# 25996,"Star Is Born, A (1954)",Drama|Musical
# 26285,Dark Star (1974),Comedy|Sci-Fi|Thriller
# 26435,Starting Over (1979),Comedy|Romance
# 26487,Star 80 (1983),Drama
# 26488,"Star Chamber, The (1983)",Action|Crime|Drama|Thriller
# 27488,Stark Raving Mad (2002),Action|Comedy|Crime
# 27692,And Starring Pancho Villa as Himself (2003),Action|Comedy|Drama|War
# 27793,Starship Troopers 2: Hero of the Federation (2004),Action|Horror|Sci-Fi|War
# 31284,"Star Is Born, A (1976)",Drama|Musical|Romance
# 33049,It Started in Naples (1960),Comedy|Drama
# 33493,Star Wars: Episode III - Revenge of the Sith (2005),Action|Adventure|Sci-Fi
# 34473,"Star, The (1952)",Drama
# 39052,Star Wreck: In the Pirkinning (2005),Action|Comedy|Sci-Fi
# 42422,Voices of a Distant Star (Hoshi no koe) (2003),Animation|Drama|Romance|Sci-Fi
# 51694,Starter for 10 (2006),Drama|Romance
# 53453,Starcrash (a.k.a. Star Crash) (1978),Action|Adventure|Fantasy|Sci-Fi
# 54259,Stardust (2007),Adventure|Comedy|Fantasy|Romance
# 56508,Starting Out in the Evening (2007),Drama
# 57183,Like Stars on Earth (Taare Zameen Par) (2007),Drama
# 58641,9 Star Hotel (Malon 9 Kochavim) (2007),Documentary
# 59392,Stargate: The Ark of Truth (2008),Action|Fantasy|Sci-Fi
# 59465,"Stars Look Down, The (1940)",Drama
# 60674,Stargate: Continuum (2008),Sci-Fi
# 60981,Fist of the North Star (1986),Action|Animation
# 61160,Star Wars: The Clone Wars (2008),Action|Adventure|Animation|Sci-Fi
# 62729,Niko & the Way to the Stars (a.k.a. The Flight Before Christmas) (Niko - Lent��j��n poika) (2008),Adventure|Animation|Children|Drama|Fantasy
# 62834,Babylon 5: The Legend of the Rangers: To Live and Die in Starlight (2002),Sci-Fi
# 64508,Starship Troopers 3: Marauder (2008),Action|Sci-Fi|War
# 67675,Star of Midnight (1935),Comedy|Mystery|Romance
# 68358,Star Trek (2009),Action|Adventure|Sci-Fi|IMAX
# 70331,My Stars (Mes stars et moi) (2008),Comedy
# 70531,"Star Packer, The (1934)",Action|Romance|Western
# 71156,"Men Who Stare at Goats, The (2009)",Action|Comedy|Drama
# 71327,Bright Star (2009),Drama|Romance
# 71758,"Cloud-Capped Star, The (Meghe Dhaka Tara) (1960)",Drama
# 72304,Fires Were Started (1943),Documentary|Drama
# 75818,Afghan Star (2009),Documentary
# 76714,Five Star Final (1931),Drama
# 78635,Under the North Star (T����ll�� Pohjant��hden alla) (2009),Drama|Romance|War
# 79006,Empire of Dreams: The Story of the 'Star Wars' Trilogy (2004),Documentary
# 79065,Thank Your Lucky Stars (1943),Comedy|Musical
# 80158,Cartoon All-Stars to the Rescue (1990),Animation|Children|Comedy|Drama|Fantasy
# 81274,Under the Stars (Bajo las estrellas) (2007),Drama
# 82680,Stars in My Crown (1950),Drama|Western
# 83071,"North Star, The (1943)",Drama|Musical|Romance|War
# 83316,"Bingo Long Traveling All-Stars & Motor Kings, The (1976)",Comedy
# 84414,All-Star Superman (2011),Action|Adventure|Animation|Sci-Fi
# 86263,Grown Up Movie Star (2009),Drama
# 87415,Lucky Star (1929),Drama|Romance
# 88055,"Missing Star, The (La stella che non c'��) (2006)",Drama
# 89829,"Star Witness, The (1931)",Drama
# 90554,"Book of Stars, The (1999)",Drama
# 90769,Starsuckers (2009),Documentary
# 91268,"Plough and the Stars, The (1936)",Drama
# 92448,Bucky Larson: Born to Be a Star (2011),Comedy
# 92481,Third Star (2010),Comedy|Drama
# 93422,Starbuck (2011),Comedy
# 94076,Position Among The Stars (Stand van de Sterren) (2010),Documentary
# 98241,Starry starry night (Xing kong) (2011),Children|Drama|Fantasy
# 98633,My Lucky Stars (Fuk sing go jiu) (1985),Action|Comedy
# 100089,Star Wars Uncut: Director's Cut (2012),Action|Animation|Comedy|Sci-Fi|Western
# 100185,Starlet (2012),Drama
# 100370,Prinsessa (Starring Maja) (2009),Drama
# 100729,Starship Troopers: Invasion (2012),Action|Animation|Sci-Fi|War
# 101166,And Now the Screaming Starts! (1973),Horror|Thriller
# 101260,StarStruck (2010),Comedy|Musical
# 102445,Star Trek Into Darkness (2013),Action|Adventure|Sci-Fi|IMAX
# 103107,20 Feet from Stardom (Twenty Feet from Stardom) (2013),Documentary
# 103210,Fullmetal Alchemist: The Sacred Star of Milos (2011),Action|Adventure|Animation
# 103561,Big Star: Nothing Can Hurt Me (2012),Documentary
# 103695,"Starfighters, The (1964)",Drama
# 103986,Stars in Shorts (2012),Comedy
# 105089,Louis Theroux: Twilight of the Porn Stars (2012),Documentary
# 105563,McKenna Shoots for the Stars (2012),Children|Drama
# 105985,Man on a Mission: Richard Garriott's Road to the Stars (2010),Documentary
# 106344,"Starving Games, The (2013)",Comedy
# 107096,Three Stars (2010),Documentary
# 107137,Star Trek: Of Gods and Men (2007),Action|Adventure|Sci-Fi
# 107306,Gurren Lagann: The Lights in the Sky are Stars (Gekij�� ban Tengen toppa guren ragan: Ragan hen) (2009),Adventure|Animation|Drama|Sci-Fi|War
# 107903,Stars (1959),Drama|War
# 108196,Starflight: The Plane That Couldn't Land (1983),Drama|Sci-Fi
# 109713,Star Wars: Threads of Destiny (2014),Action|Adventure|Sci-Fi
# 109925,"It Is Written in the Stars, Inspector Palmu (T��hdet kertovat, komisario Palmu) (1962)",Crime|Mystery
# 110110,Starred Up (2013),Drama
# 110179,Stardust (1974),Drama
# 111921,The Fault in Our Stars (2014),Drama|Romance
# 112070,Maps to the Stars (2014),Drama
# 112395,Belle Starr (1941),Western
# 115545,"Star for Two, A (1991)",Drama|Romance
# 115558,Amazon Jack 2: The Movie Star (a.k.a. Hugo the Movie Star) (Jungledyret 2 - den store filmhelt) (1996),Animation|Children|Musical|Romance
# 115703,"The Hire: Star, The (2001)",Action|Comedy
# 116000,Starship Invasions (1977),Sci-Fi
# 116405,A Star Athlete (1937),Comedy|Drama
# 117434,Starry Eyes (2014),Horror
# 121211,Major Movie Star (2008),Adventure|Comedy|Drama|War
# 122825,Starlift (1951),(no genres listed)
# 124131,Lewis Black: Stark Raving Black (2009),Comedy
# 125417,Stars and Stripes Forever (1952),Drama
# 125910,Stars Above (2012),(no genres listed)
# 127640,I Start Counting (1970),Thriller
# 130516,Glowing Stars (2009),Drama
# 131050,Stargate SG-1 Children of the Gods - Final Cut (2009),Adventure|Sci-Fi|Thriller
